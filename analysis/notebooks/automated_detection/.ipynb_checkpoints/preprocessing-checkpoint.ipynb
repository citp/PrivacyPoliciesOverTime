# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from gensim import corpora, models
import nltk
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
from nltk.tokenize import sent_tokenize
import spacy

import numpy as np
import math
import random

import os
import sys
import re
import itertools
import collections

import pickle

from matplotlib import pyplot as plt
import seaborn as sns

# %%
import mistune
import mistune.renderers

# %%
nlp = spacy.load("en_core_web_lg")
nlp.max_length *= 5

# %% [markdown]
# # Load data

# %%
#Load the data
with open("../../data/deduped_policy_text_v11no_html_with_links_and_emails.pickle", "rb") as f:
    df_all = pickle.load(f)
df_sample = df_all.sample(1000)

# %%
df = df_sample

# %% [markdown]
# # Clean up

# %%
valid_end_punct = set((".","!","?",'"',"'"))
def strip_incomplete_sentences(text,flag_components=False):
    sentences = nltk.tokenize.sent_tokenize(text)
    if len(sentences) == 0:
        return ""
    words = nltk.tokenize.word_tokenize(sentences[-1])
    if not words[-1] in valid_end_punct:
        if flag_components:
            sentences[-1] = "_cut_" + sentences[-1] + "_cut_"
        else:
            sentences = sentences[:-1]
    return " ".join(sentences)

class StraightTextRenderer(mistune.renderers.BaseRenderer):
    
    def __init__(self,flag_components):
        self.flag_components = flag_components
    
    def text(self, text):
        return text

    def link(self, link, text=None, title=None):
        if text is None:
            return "link"
        else:
            return text

    def image(self, src, alt="", title=None):
        return ""

    def emphasis(self, text):
        return text

    def strong(self, text):
        return text

    def codespan(self, text):
        if self.flag_components:
            return "\n_codespan_%s_codespan\n" % text
        else:
            return "\n"

    def linebreak(self):
        if self.flag_components:
            return "\n_line break_\n"
        else:
            return "\n"

    def inline_html(self, html):
        if self.flag_components:
            return '\n_inline-html_%s_inline-html_\n' % html
        else:
            #HTML isn't prose
            return "\n"

    def paragraph(self, text):
        if text == '': return text
        paragraphs = text.split('\n')
        paragraphs = (strip_incomplete_sentences(para,flag_components=self.flag_components) for para in paragraphs)
        text = "\n".join(paragraphs)
        if self.flag_components:
            return "\n_paragraph_\n" + text + "\n_paragraph_\n"
        else:
            return text + "\n"

    def heading(self, text, level):
        if self.flag_components:
            return '\n_heading %d_ %s\n' % (level,text)
        else:
            #Headings aren't prose
            return "\n"

    def newline(self):
        if self.flag_components:
            return '\n_newline_\n'
        else:
            return "\n"

    def thematic_break(self):
        if self.flag_components:
            return '\n_thematic-break_\n'
        else:
            return "\n"

    def block_text(self, text):
        if self.flag_components:
            return '\n_block-text_%s_block-text_\n' % text
        else:
            return "%s\n" % text

    def block_code(self, code, info=None):
        if self.flag_components:
            if not code.strip():
                return "\n"
            else:
                return '\n_block-code_%s_block-code_\n' % code
        else:
            #This stuff usually isn't code, treat it as a paragraph
            return self.paragraph(code)

    def block_quote(self, text):
        if self.flag_components:
            return '\n_block-quote_%s_block-quote_\n' % text
        else:
            return "%s\n" % text

    def block_html(self, html):
        if self.flag_components:
            return "\n_block-html_%s_block-html\n" % html
        else:
            #HTML isn't prose
            return  "\n"

    def block_error(self, html):
        if self.flag_components:
            return "\n_block-error_%s_block-error\n" % html
        else:
            #Errors aren't prose
            return "\n"

    def list(self, text, ordered, level, start=None):
        if text == '': return text
        paragraphs = text.split('\n')
        paragraphs = [strip_incomplete_sentences(para,flag_components=self.flag_components) for para in paragraphs]
        text = "\n".join(paragraphs)
        if self.flag_components:
            return "\n_list %s %d_\n%s\n_list_\n" % (ordered, level, text)
        else:
            #Lists are inconsistent in how many sentences they represent
            #Rule: If all of the rows are sentences, then we'll keep them
            #If any stripped list item is empty, return empty for everything
            if any((not list_item.strip() for list_item in paragraphs)):
                return "\n"
            else:
                return text + "\n"

    def list_item(self, text, level):
        return "%s\n" % text
    
    def strikethrough(self, text):
        return ""
    
    def table(self, text):
        if self.flag_components:
            return '\n_table_%s_table_\n' % (text)
        else:
            return "\n"
    
    def table_cell(self, content, align=None, is_head=False):
        if self.flag_components:
            return '\n_cell_\n'
        else:
            return ""
    
    def table_head(self, content):
        if self.flag_components:
            return '\n_head_\n'
        else:
            return ""
        
    def table_row(self, content):
        if self.flag_components:
            return '_row_%s_row_\n' % content
        else:
            return ""
        
    def table_body(self, content):
        if self.flag_components:
            return '_body_%s_body_\n' % content
        else:
            return ""
    
markdown = mistune.create_markdown(renderer=StraightTextRenderer(False))
markdown_debug = mistune.create_markdown(renderer=StraightTextRenderer(True))

#Install mistune plugins
import mistune.plugins
mistune.plugins.plugin_table(markdown)
mistune.plugins.plugin_strikethrough(markdown)
mistune.plugins.plugin_table(markdown_debug)
mistune.plugins.plugin_strikethrough(markdown_debug)

def clean(policy_text):
    return markdown(policy_text)

def clean_debug(policy_text):
    return markdown_debug(policy_text)

# %%
df["policy_text_cleaned"] = df.policy_text.map(clean)

# %% [markdown]
# # Remove website-specific terms

# %% [markdown]
# #### Regex substitutions

# %%
truste_regex = re.compile(r"(?<![a-z])truste(?![a-z])",flags=re.IGNORECASE)
#https://emailregex.com/
email_regex = re.compile(r"(?:[a-z0-9!#$%&'*+/=?^_`{|}~-]+(?:\.[a-z0-9!#$%&'*+/=?^_`{|}~-]+)*|\"(?:[\x01-\x08\x0b\x0c\x0e-\x1f\x21\x23-\x5b\x5d-\x7f]|\\[\x01-\x09\x0b\x0c\x0e-\x7f])*\")@(?:(?:[a-z0-9](?:[a-z0-9-]*[a-z0-9])?\.)+[a-z0-9](?:[a-z0-9-]*[a-z0-9])?|\[(?:(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)\.){3}(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?|[a-z0-9-]*[a-z0-9]:(?:[\x01-\x08\x0b\x0c\x0e-\x1f\x21-\x5a\x53-\x7f]|\\[\x01-\x09\x0b\x0c\x0e-\x7f])+)\])",flags=re.IGNORECASE)
#https://gist.github.com/gruber/8891611
url_regex = re.compile(r"(?i)\b((?:https?:(?:/{1,3}|[a-z0-9%])|[a-z0-9.\-]+[.](?:com|net|org|edu|gov|mil|aero|asia|biz|cat|coop|info|int|jobs|mobi|museum|name|post|pro|tel|travel|xxx|ac|ad|ae|af|ag|ai|al|am|an|ao|aq|ar|as|at|au|aw|ax|az|ba|bb|bd|be|bf|bg|bh|bi|bj|bm|bn|bo|br|bs|bt|bv|bw|by|bz|ca|cc|cd|cf|cg|ch|ci|ck|cl|cm|cn|co|cr|cs|cu|cv|cx|cy|cz|dd|de|dj|dk|dm|do|dz|ec|ee|eg|eh|er|es|et|eu|fi|fj|fk|fm|fo|fr|ga|gb|gd|ge|gf|gg|gh|gi|gl|gm|gn|gp|gq|gr|gs|gt|gu|gw|gy|hk|hm|hn|hr|ht|hu|id|ie|il|im|in|io|iq|ir|is|it|je|jm|jo|jp|ke|kg|kh|ki|km|kn|kp|kr|kw|ky|kz|la|lb|lc|li|lk|lr|ls|lt|lu|lv|ly|ma|mc|md|me|mg|mh|mk|ml|mm|mn|mo|mp|mq|mr|ms|mt|mu|mv|mw|mx|my|mz|na|nc|ne|nf|ng|ni|nl|no|np|nr|nu|nz|om|pa|pe|pf|pg|ph|pk|pl|pm|pn|pr|ps|pt|pw|py|qa|re|ro|rs|ru|rw|sa|sb|sc|sd|se|sg|sh|si|sj|Ja|sk|sl|sm|sn|so|sr|ss|st|su|sv|sx|sy|sz|tc|td|tf|tg|th|tj|tk|tl|tm|tn|to|tp|tr|tt|tv|tw|tz|ua|ug|uk|us|uy|uz|va|vc|ve|vg|vi|vn|vu|wf|ws|ye|yt|yu|za|zm|zw)/)(?:[^\s()<>{}\[\]]+|\([^\s()]*?\([^\s()]+\)[^\s()]*?\)|\([^\s]+?\))+(?:\([^\s()]*?\([^\s()]+\)[^\s()]*?\)|\([^\s]+?\)|[^\s`!()\[\]{};:'\".,<>?«»“”‘’])|(?:(?<!@)[a-z0-9]+(?:[.\-][a-z0-9]+)*[.](?:com|net|org|edu|gov|mil|aero|asia|biz|cat|coop|info|int|jobs|mobi|museum|name|post|pro|tel|travel|xxx|ac|ad|ae|af|ag|ai|al|am|an|ao|aq|ar|as|at|au|aw|ax|az|ba|bb|bd|be|bf|bg|bh|bi|bj|bm|bn|bo|br|bs|bt|bv|bw|by|bz|ca|cc|cd|cf|cg|ch|ci|ck|cl|cm|cn|co|cr|cs|cu|cv|cx|cy|cz|dd|de|dj|dk|dm|do|dz|ec|ee|eg|eh|er|es|et|eu|fi|fj|fk|fm|fo|fr|ga|gb|gd|ge|gf|gg|gh|gi|gl|gm|gn|gp|gq|gr|gs|gt|gu|gw|gy|hk|hm|hn|hr|ht|hu|id|ie|il|im|in|io|iq|ir|is|it|je|jm|jo|jp|ke|kg|kh|ki|km|kn|kp|kr|kw|ky|kz|la|lb|lc|li|lk|lr|ls|lt|lu|lv|ly|ma|mc|md|me|mg|mh|mk|ml|mm|mn|mo|mp|mq|mr|ms|mt|mu|mv|mw|mx|my|mz|na|nc|ne|nf|ng|ni|nl|no|np|nr|nu|nz|om|pa|pe|pf|pg|ph|pk|pl|pm|pn|pr|ps|pt|pw|py|qa|re|ro|rs|ru|rw|sa|sb|sc|sd|se|sg|sh|si|sj|Ja|sk|sl|sm|sn|so|sr|ss|st|su|sv|sx|sy|sz|tc|td|tf|tg|th|tj|tk|tl|tm|tn|to|tp|tr|tt|tv|tw|tz|ua|ug|uk|us|uy|uz|va|vc|ve|vg|vi|vn|vu|wf|ws|ye|yt|yu|za|zm|zw)\b/?(?!@)))",flags=re.IGNORECASE)

# %%
def truste_sub(text):
    return truste_regex.sub("TrustArc",text)

def email_sub(text):
    return email_regex.sub("email_sub",text)

def url_sub(text):
    return url_regex.sub("url_sub",text)

df["policy_text_cleaned"] = df.policy_text_cleaned.map(truste_sub).map(email_sub).map(url_sub)

# %% [markdown]
# #### NER

# %%
# First pass -- find entities

TAGS_TO_SWAP = [
    "ORG",
    "PERSON",
    #    "FAC",
    #"WORK_OF_ART",
]

def get_entities(text):
    entities = set()
    doc = nlp(text)
    for entity in sorted(doc.ents, key=lambda x: -len(x.text)):
        if entity.label_ in TAGS_TO_SWAP:
            entities.add(entity.text.lower())
    return entities

entities = sorted(list(set(itertools.chain.from_iterable(df.policy_text_cleaned.map(get_entities)))),key=len,reverse=True)
len(entities)
# Out:
# 3632

# %%
blacklist = ["email","url","number"]
entities_filtered = list(filter(lambda x: x in blacklist or any(map(str.isalpha,x)),entities))
print(len(entities_filtered))
print(entities_filtered)
# Out:
# 3619
# ['the site"s publisher terms and conditions and advertiser terms and conditions', 'the controlling the assault of non-solicited pornography and marketing act', 'the canadian self-regulatory principles for online behavioral advertising', 'registration information, publishing information and payment information', "the university's office of academic records and university registrar", 'the personal information protection and electronic documents act', 'the self-regulatory principles for online behavioral advertising', 'the legislative and judicial branches of the federal government', 'hair loss guide and information | baldness prevention,treatment', 'personal information protection and electronic documents act', 'the european general data protection regulation (regulation', "children's hospital and regional medical center (children's", 'the office of public relations and marketing communication', 'the data protection commissioner/national consumer council', 'the commission nationale de l’informatique et des libertés', 'the third party advertising service provider or advertiser', 'the office of public relations & marketing communications', 'the cbs interactive business partner advertising opt-out', 'the privacy and personal information protection act 1998', 'a third party advertising service provider or advertiser', 'the internet corporation for assigned names and numbers', 'the nsw school certificate or higher school certificate', 'the health insurance portability and accountability act', 'the national information infrastructure protection act', 'the chris human resource management information system', 'the american institute of certified public accountants', 'mining gold corporation nevada processing center, inc', 'the european interactive digital advertising alliance', 'the european interactive advertising digital alliance', 'physical contact address and internet contact address', 'movado group nederland b.v.\n\n\n\n\n\n\n\n\n\n\n\n\n\nbettlachstr', 'the federal children’s online privacy protection act', 'the higher school certificate and school certificate', 'google analytics demographics and interest reporting', 'the school certificate and higher school certificate', "the federal children's online privacy protection act", 'the great ormond street hospital children’s charity', 'bureau of consumer protection, office of the nevada', 'service providers, agents and related third parties', 'the privacy and personal information protection act', 'the u.s. department of commerce safe harbor program', 'cardinal health’s ethics and compliance department', 'la política de privacidad y las condiciones de uso', 'the consumer protection in electronic commerce act', 'chris human resource management information system', 'european interactive digital advertising alliance', 'the swiss federal data protection and information', 'the statistical information for internal analysis', "the u.s. children's online privacy protection act", 'certain third party advertising service providers', 'non-personal information and personal information', 'the internet, company uses technology information', 'the national council of the boy scouts of america', 'electronic fare media program or website services', 'personal information and non-personal information', "the children's online privacy and protection act", 'the university of washington school of dentistry', 'choicepoint insurance consumer center associates', 'the muscle maximizer uses technology information', 'the sony pictures networks india private limited', 'these third party advertising service providers', 'the federal australian music examinations board', 'tracking technologies with personal information', 'individual information means survey information', 'the url services agreement terms and conditions', 'great ormond street hospital children’s charity', 'california business & professions code section', 'the trustarc safe harbor compliance department', 'freedom of information and privacy coordinator',  ...

# %%
entity_re = re.compile(r"\b(?:%s)\b" % "|".join(map(re.escape,entities_filtered)),re.IGNORECASE)
num_regex = re.compile(r"(?<![a-z])\d+(\.\d+)?(?![a-z])",flags=re.IGNORECASE)

def entity_sub(text):
    return entity_re.sub("ENTITY",text)

def num_sub(text):
    return num_regex.sub("NUMBER",text)

df["policy_tex_cleaned"] = df.policy_text_cleaned.map(entity_sub).map(num_sub)

# %% [markdown]
# # N-Grams

# %%
def get_ngrams(text,n=2):
    ngrams = set()
    for sentence in nltk.tokenize.sent_tokenize(text):
        if n is None:
            sentence = sys.intern(sentence)
            ngrams.add(sentence)
            continue
        words = nltk.tokenize.word_tokenize(sentence)
        words = filter(str.isalnum,words)
        phrases = (" ".join(phrase) for phrase in nltk.ngrams(words,n))
        phrases = map(sys.intern,phrases)
        ngrams.update(phrases)
    return ngrams
        
counters = {}
for ys, sub_df in df.groupby("year_season"):
    counters[ys] = collections.Counter(itertools.chain.from_iterable(sub_df["policy_text_cleaned"].map(get_ngrams)))

# %%
counters[ys]
# Out:
# Counter({'obtain a': 2,
#          'a better': 2,
#          'or disable': 2,
#          'send information': 2,
#          'better ENTITY': 4,
#          'that the': 12,
#          'your explicit': 2,
#          'you is': 6,
#          'information in': 10,
#          'the erasure': 2,
#          'on the': 22,
#          'We also': 9,
#          'These cookies': 4,
#          'explicit permission': 1,
#          'use this': 9,
#          'use cookies': 20,
#          'how to': 8,
#          'information about': 24,
#          'this ENTITY': 26,
#          'and ENTITY': 29,
#          'have concerns': 3,
#          'ENTITY you': 25,
#          'signifies your': 1,
#          'the Eupedia': 1,
#          'hold about': 3,
#          'you do': 15,
#          'also have': 5,
#          'to identify': 7,
#          'when you': 22,
#          'logged in': 4,
#          'and send': 2,
#          'you would': 8,
#          'will never': 1,
#          'and campaign': 1,
#          'uses cookies': 7,
#          'If you': 27,
#          'the functionality': 2,
#          'improve the': 11,
#          'can present': 1,
#          'Cookies are': 8,
#          'may be': 23,
#          'your ENTITY': 28,
#          'you when': 12,
#          'is committed': 5,
#          'a copy': 5,
#          'hold for': 1,
#          'to complete': 2,
#          'complete or': 1,
#          'to gather': 3,
#          'files that': 4,
#          'without your': 6,
#          'incomplete or': 2,
#          'Continued use': 2,
#          'agreeing to': 1,
#          'the ENTITY': 33,
#          'to enhance': 3,
#          'nor use': 1,
#          'never sell': 2,
#          'on your': 17,
#          'to third': 10,
#          'right to': 14,
#          'in the': 22,
#          'protect the': 9,
#          'ENTITY so': 4,
#          'if you': 16,
#          'copy of': 5,
#          'functionality of': 3,
#          'and confidentiality': 4,
#          'enhance the': 1,
#          'ENTITY is': 30,
#          'tracking notably': 1,
#          'remove your': 3,
#          'acceptance of': 5,
#          'confidentiality of': 4,
#          'or questions': 2,
#          'policies please': 1,
#          'You may': 14,
#          'ENTITY that': 26,
#          'at any': 15,
#          'hesitate to': 1,
#          'are small': 5,
#          'with a': 12,
#          'to delete': 4,
#          'ENTITY we': 27,
#          'make changes': 6,
#          'are used': 4,
#          'if it': 3,
#          'you may': 24,
#          'is to': 4,
#          'for ENTITY': 19,
#          'we will': 23,
#          'do not': 25,
#          'have logged': 1,
#          'that information': 10,
#          'ENTITY by': 18,
#          'performance of': 4,
#          'you with': 15,
#          'Eupedia ENTITY': 1,
#          'to our': 22,
#          'small text': 5,
#          'the performance': 4,
#          'might be': 3,
#          'about you': 16,
#          'it changes': 1,
#          'personally identifying': 2,
#          'or you': 4,
#          'storing your': 1,
#          'changes to': 13,
#          'permission nor': 1,
#          'our visitors': 8,
#          'gather and': 1,
#          'in on': 1,
#          'campaign tracking': 1,
#          'computer by': 1,
#          'visit to': 9,
#          'you might': 1,
#          'Our ENTITY': 11,
#          'To do': 2,
#          'about any': 3,
#          'like us': 1,
#          'We may': 20,
#          'cookies for': 4,
#          'a right': 3,
#          'protecting and': 2,
#          'of cookies': 7,
#          'distribute ENTITY': 1,
#          'that are': 13,
#          'of it': 3,
#          'may make': 4,
#          'ENTITY addresses': 11,
#          'can find': 1,
#          'about cookies': 2,
#          'or correct': 2,
#          'any aspect': 1,
#          'to provide': 24,
#          'adverts that': 1,
#          'on Wikipedia': 1,
#          'ENTITY experience': 3,
#          'believe that': 4,
#          'do so': 16,
#          'find more': 1,
#          'have the': 12,
#          'changes in': 4,
#          'the future': 7,
#          'registering we': 1,
#          'ENTITY uses': 16,
#          'not accept': 3,
#          'please ENTITY': 17,
#          'and the': 19,
#          'ENTITY your': 5,
#          'By continuing': 2,
#          'your preferences': 2,
#          'respecting your': 1,
#          'to remove': 2,
#          'ENTITY ENTITY': 32,
#          'in this': 14,
#          'our ENTITY': 32,
#          'You can': 14,
#          'learn how': 1,
#          'to other': 15,
#          'with adverts': 1,
#          'we hold': 4,
#          'information we': 13,
#          'also use': 11,
#          'You also': 6,
#          'the right': 15,
#          'are placed': 2,
#          'more information': 9,
#          'visitors and': 5,
#          'and to': 18,
#          'interested in': 3,
#          'ENTITY will': 20,
#          'of ENTITY': 31,
#          'cookies here': 1,
#          'other ENTITY': 29,
#          'may ENTITY': 17,
#          'of this': 17,
#          'your computer': 15,
#          'use of': 25,
#          'for unapproved': 1,
#          'You have': 6,
#          'delete or': 2,
#          'Please ENTITY': 5,
#          'so that': 6,
#          'information to': 17,
#          'correct that': 1,
#          'can learn': 1,
#          'committed to': 10,
#          'ENTITY or': 32,
#          'or distribute': 1,
#          'addresses other': 1,
#          'They are': 1,
#          'you or': 8,
#          'not hesitate': 1,
#          'present you': 1,
#          'parties to': 8,
#          'your acceptance': 4,
#          'by ENTITY': 23,
#          'explicit acceptance': 1,
#          'our use': 4,
#          'third parties': 22,
#          'disable cookies': 3,
#          'ENTITY then': 3,
#          'to ENTITY': 31,
#          'of our': 28,
#          'erasure of': 2,
#          'cookies on': 5,
#          'use it': 6,
#          'identifying information': 3,
#          'widely used': 1,
#          'that they': 6,
#          'for you': 6,
#          'inaccurate you': 1,
#          'any time': 16,
#          'questions about': 8,
#          'of your': 24,
#          'ENTITY to': 32,
#          'This ENTITY': 27,
#          'will further': 1,
#          'would like': 9,
#          'to protecting': 2,
#          'and respecting': 1,
#          'asked to': 5,
#          'notably ENTITY': 1,
#          'you visit': 18,
#          'or obtain': 2,
#          'text files': 5,
#          'be asked': 5,
#          'cookies are': 7,
#          'ENTITY purposes': 5,
#          'that you': 20,
#          'be interested': 2,
#          'concerns or': 2,
#          'ENTITY policies': 18,
#          'sell or': 4,
#          'are widely': 1,
#          'parties without': 2,
#          'When registering': 1,
#          'you are': 23,
#          'ENTITY the': 23,
#          'of the': 29,
#          'us to': 18,
#          'ask us': 3,
#          'so please': 2,
#          'used by': 12,
#          'to protect': 19,
#          'identify your': 2,
#          'to ask': 5,
#          'browse the': 2,
#          'to this': 16,
#          'used to': 16,
#          'aspect of': 1,
#          'provide you': 10,
#          'continuing to': 2,
#          'by storing': 1,
#          'ENTITY at': 20,
#          'not use': 7,
#          'have a': 8,
#          'placed on': 2,
#          'other personally': 3,
#          'are agreeing': 1,
#          'ENTITY signifies': 1,
#          'then please': 2,
#          'further ENTITY': 3,
#          'to browse': 1,
#          'they can': 5,
#          'by third': 4,
#          'or inaccurate': 2,
#          'accept the': 1,
#          'you have': 23,
#          'ENTITY if': 7,
#          'preferences to': 4,
#          'to improve': 15,
#          'is incomplete': 2,
#          'ENTITY and': 33,
#          'the information': 19,
#          'unapproved ENTITY': 1,
#          'please do': 4,
#          'it for': 3,
#          'you believe': 5,
#          'note that': 11,
#          'some parts': 2,
#          'to receive': 10,
#          'measures to': 9,
#          'name the': 2,
#          'we do': 14,
#          'delivered to': 2,
#          'discloses information': 1,
#          'not cover': 4,
#          'they do': 1,
#          'disclosure or': 1,
#          'or others': 5,
#          'submit such': 1,
#          'may use': 18,
#          'technical information': 4,
#          'ENTITY applies': 11,
#          'be delivered': 1,
#          'your permission': 1,
#          'ENTITY s': 15,
#          'it may': 7,
#          'helping to': 1,
#          'choose to': 12,
#          'others who': 3,
#          'adopt appropriate': 1,
#          'alteration disclosure': 1,
#          'signify your': 1,
#          'using this': 1,
#          'ENTITY please': 13,
#          'time the': 1,
#          'such information': 12,
#          'ENTITY may': 29,
#          'the operating': 3,
#          'to help': 14,
#          'they will': 1,
#          'subscribe to': 3,
#          'for the': 24,
#          'they interact': 1,
#          'ENTITY revise': 1,
#          'and sometimes': 2,
#          'we are': 9,
#          'has the': 5,
#          'will collect': 3,
#          'ENTITY not': 3,
#          'with other': 7,
#          'have given': 3,
#          'feedback you': 1,
#          'ENTITY utilized': 1,
#          'future emails': 2,
#          'in which': 6,
#          'browser name': 1,
#          'any ENTITY': 17,
#          'the ad': 2,
#          'ENTITY related': 4,
#          'which ENTITY': 6,
#          'track information': 3,
#          'identification information': 1,
#          'By using': 8,
#          'share generic': 1,
#          'activities ENTITY': 1,
#          'and in': 7,
#          'administer activities': 1,
#          'them from': 2,
#          'these third': 4,
#          'to alert': 3,
#          'things deliver': 1,
#          'We encourage': 9,
#          'or destruction': 1,
#          'supply personally': 1,
#          'when cookies': 3,
#          'or rent': 5,
#          'To send': 1,
#          'ENTITY information': 16,
#          'use feedback': 1,
#          'decides to': 1,
#          'sometimes to': 1,
#          'given us': 3,
#          'ENTITY has': 18,
#          'ENTITY whenever': 1,
#          'other similar': 2,
#          'can always': 1,
#          'this page': 7,
#          'rent ENTITY': 3,
#          'purposes outlined': 1,
#          'a notification': 1,
#          'ENTITY anonymously': 2,
#          'may share': 7,
#          'security measures': 10,
#          'collected from': 7,
#          'other things': 1,
#          'by advertising': 2,
#          'to others': 4,
#          'ENTITY means': 1,
#          'is your': 1,
#          'information collected': 15,
#          'to any': 15,
#          'of most': 1,
#          'with our': 12,
#          'ENTITY would': 1,
#          'help us': 9,
#          'provide to': 8,
#          'interest to': 8,
#          'periodically and': 2,
#          'for as': 3,
#          'be deemed': 2,
#          'deliver targeted': 1,
#          'page for': 1,
#          'for purposes': 4,
#          'share your': 8,
#          'in a': 14,
#          'online advertisement': 2,
#          'compile non': 1,
#          'ad server': 2,
#          'refuse to': 3,
#          'that some': 3,
#          'If they': 1,
#          'send ENTITY': 4,
#          'destruction of': 1,
#          'ENTITY username': 1,
#          'governs the': 1,
#          'to to': 1,
#          'any changes': 7,
#          'agreed to': 2,
#          'provided that': 3,
#          'available on': 4,
#          'for any': 11,
#          'activities on': 2,
#          'may prevent': 1,
#          'they send': 1,
#          'use the': 13,
#          'about how': 9,
#          'ENTITY visit': 1,
#          'other activities': 2,
#          'sell trade': 3,
#          'against unauthorized': 2,
#          'manner in': 1,
#          'make available': 1,
#          'and discloses': 1,
#          'ENTITY transaction': 1,
#          'the browser': 4,
#          'that may': 9,
#          'ad networks': 4,
#          'username ENTITY': 1,
#          'posting of': 2,
#          'interact with': 6,
#          'unauthorized ENTITY': 10,
#          'trade or': 3,
#          'collect ENTITY': 15,
#          'information except': 1,
#          'We adopt': 1,
#          'each time': 2,
#          'each ENTITY': 5,
#          'ENTITY following': 2,
#          'computer and': 3,
#          'will be': 22,
#          'ENTITY each': 3,
#          'about them': 1,
#          'or to': 18,
#          'and technical': 6,
#          'we include': 2,
#          'ENTITY about': 17,
#          'cookies to': 15,
#          'our behalf': 5,
#          'advertisements that': 2,
#          'the use': 12,
#          'places cookies': 1,
#          'mailing list': 1,
#          's ENTITY': 9,
#          'that it': 7,
#          'appearing on': 1,
#          'think will': 1,
#          'collection storage': 1,
#          'we make': 9,
#          'use your': 10,
#          'We will': 10,
#          'ENTITY such': 23,
#          'the main': 1,
#          'protect ENTITY': 11,
#          'a variety': 9,
#          'ENTITY this': 4,
#          'aggregated ENTITY': 2,
#          'post a': 1,
#          'page of': 3,
#          'resources we': 1,
#          'applies to': 6,
#          'product or': 4,
#          'send you': 8,
#          'your information': 18,
#          'may collect': 13,
#          'time they': 2,
#          'detailed ENTITY': 2,
#          'form and': 2,
#          'the type': 8,
#          'to supply': 1,
#          'variety of': 9,
#          'targeted advertisements': 2,
#          'ENTITY features': 2,
#          'parts of': 4,
#          'main page': 1,
#          'a form': 3,
#          'instructions at': 2,
#          'outlined may': 1,
#          'ENTITY fill': 1,
#          'enhance ENTITY': 1,
#          'as the': 8,
#          'or ENTITY': 27,
#          'responsibility to': 1,
#          'means of': 3,
#          'refuse cookies': 4,
#          'visit our': 6,
#          'ENTITY from': 19,
#          'behalf such': 1,
#          'We do': 15,
#          'a ENTITY': 25,
#          'of connection': 1,
#          'appropriate ENTITY': 1,
#          'browser places': 1,
#          'ENTITY does': 15,
#          'ENTITY offered': 3,
#          'the discretion': 1,
#          'all ENTITY': 9,
#          'discretion to': 2,
#          'will post': 8,
#          'from receiving': 3,
#          'ENTITY only': 7,
#          'following the': 3,
#          'updated date': 1,
#          'processing practices': 1,
#          'type of': 8,
#          'notification on': 1,
#          'so note': 1,
#          'operating system': 6,
#          'as appropriate': 2,
#          'fill out': 3,
#          'allow the': 2,
#          'collect about': 4,
#          'ENTITY collects': 7,
#          'ENTITY in': 22,
#          'receive about': 2,
#          'not ENTITY': 10,
#          'emails we': 2,
#          'to when': 2,
#          'ENTITY alteration': 1,
#          'cookies or': 10,
#          'out ENTITY': 2,
#          'who use': 1,
#          'to you': 20,
#          'engaging in': 2,
#          'continued use': 3,
#          'informed about': 2,
#          'the Internet': 13,
#          'Ads appearing': 1,
#          'and other': 23,
#          'on our': 19,
#          'to set': 2,
#          'out a': 3,
#          'each a': 1,
#          'features or': 4,
#          'they voluntarily': 1,
#          'prevent them': 1,
#          'at the': 12,
#          'and become': 1,
#          'acknowledge and': 2,
#          'you signify': 1,
#          'update this': 4,
#          'including but': 5,
#          'your responsibility': 1,
#          'ENTITY collection': 7,
#          'ENTITY stored': 4,
#          'of computer': 2,
#          'bottom of': 4,
#          'aware of': 6,
#          'include ENTITY': 6,
#          'respond to': 11,
#          'collects uses': 1,
#          'of each': 5,
#          'from engaging': 1,
#          'cookies by': 4,
#          'ENTITY etc': 4,
#          'receiving future': 2,
#          'ENTITY with': 19,
#          'news ENTITY': 2,
#          'asked for': 1,
#          'information and': 8,
#          'advertising ENTITY': 8,
#          'ENTITY governs': 2,
#          'of ways': 2,
#          'improve our': 4,
#          'to their': 5,
#          'alert you': 2,
#          'with these': 5,
#          'most interest': 1,
#          'you provide': 13,
#          'about ENTITY': 14,
#          'but not': 5,
#          'regarding visitors': 1,
#          'they agreed': 1,
#          'to stay': 1,
#          'how we': 13,
#          'the posting': 1,
#          'agree that': 5,
#          'hard drive': 8,
#          'our mailing': 1,
#          'does not': 20,
#          'recognize your': 1,
#          'ENTITY instructions': 2,
#          'we collect': 21,
#          'not agree': 2,
#          'to recognize': 2,
#          'to us': 22,
#          'the bottom': 4,
#          'to among': 1,
#          'may include': 10,
#          'ENTITY trusted': 1,
#          'browser to': 8,
#          'an online': 4,
#          'offered by': 4,
#          'those changes': 7,
#          'will receive': 3,
#          'You acknowledge': 1,
#          'protect against': 4,
#          'practices and': 2,
#          'ENTITY decides': 1,
#          'stay informed': 1,
#          'certain ENTITY': 8,
#          'This information': 13,
#          'linked to': 7,
#          'they believe': 1,
#          'include the': 4,
#          'list they': 1,
#          'When we': 4,
#          'and processing': 8,
#          'by any': 3,
#          'the purposes': 5,
#          'information allows': 2,
#          'deemed your': 1,
#          'ENTITY can': 13,
#          'you an': 1,
#          'ENTITY news': 2,
#          'however visit': 2,
#          'among other': 1,
#          'Your continued': 3,
#          'their inquiries': 1,
#          'such as': 25,
#          'not function': 4,
#          'business and': 3,
#          'us operate': 1,
#          'personally identification': 1,
#          'and agree': 3,
#          'revise the': 1,
#          'server to': 1,
#          'date at': 3,
#          'parties for': 7,
#          'their ENTITY': 15,
#          'advertisement to': 2,
#          'ENTITY address': 29,
#          'to track': 6,
#          'information they': 3,
#          'emails that': 3,
#          'frequently check': 1,
#          'the manner': 1,
#          'sending out': 1,
#          'information with': 7,
#          'include detailed': 2,
#          'if they': 2,
#          'related activities': 1,
#          'stored on': 9,
#          'to them': 4,
#          'do we': 5,
#          'trusted ENTITY': 1,
#          'similar information': 3,
#          'agree to': 8,
#          'may not': 12,
#          'on their': 9,
#          'use our': 8,
#          'like to': 6,
#          'to the': 23,
#          'inquiries questions': 1,
#          'connection with': 8,
#          'If ENTITY': 5,
#          'computer each': 1,
#          'ENTITY subscribe': 1,
#          'to respond': 4,
#          'for those': 1,
#          'of those': 3,
#          'set their': 1,
#          'and all': 5,
#          'address to': 4,
#          'it is': 14,
#          'use ENTITY': 18,
#          'as sending': 2,
#          'to compile': 1,
#          'always refuse': 1,
#          'we think': 3,
#          'being sent': 5,
#          'those ENTITY': 8,
#          'If at': 2,
#          'operate our': 2,
#          'function properly': 3,
#          'except that': 1,
#          'to frequently': 1,
#          'when ENTITY': 3,
#          'from ENTITY': 21,
#          'and security': 5,
#          'uses maintains': 1,
#          'to update': 5,
#          'cover the': 3,
#          'of interest': 7,
#          'networks to': 4,
#          'in connection': 8,
#          'drive for': 2,
#          'are being': 2,
#          'of changes': 1,
#          'cookies allow': 4,
#          'who may': 2,
#          'become aware': 4,
#          'voluntarily submit': 1,
#          'topics we': 1,
#          'connection to': 2,
#          'purposes and': 2,
#          'not sell': 4,
#          'utilized and': 1,
#          'in certain': 4,
#          'receive emails': 1,
#          'allows ad': 1,
#          'other requests': 1,
#          'transaction information': 1,
#          'our business': 5,
#          'may set': 3,
#          'are helping': 1,
#          'non ENTITY': 1,
#          'set cookies': 1,
#          'ENTITY for': 26,
#          'ENTITY browser': 16,
#          'to refuse': 6,
#          'related product': 2,
#          'check this': 2,
#          'ENTITY periodically': 4,
#          'or administer': 1,
#          'only if': 4,
#          'purposes provided': 1,
#          'about topics': 1,
#          'or resources': 1,
#          'be of': 5,
#          'ENTITY who': 11,
#          'encourage ENTITY': 1,
#          'whenever they': 1,
#          'believe will': 2,
#          'may choose': 6,
#          'storage and': 4,
#          'their hard': 1,
#          'the updated': 2,
#          'ENTITY of': 24,
#          'maintains and': 1,
#          'questions other': 1,
#          'generic aggregated': 1,
#          'us your': 2,
#          'not linked': 4,
#          'ways including': 1,
#          'may however': 4,
#          'of modifications': 1,
#          'ENTITY regarding': 5,
#          'Internet ENTITY': 5,
#          'system and': 2,
#          'processing of': 6,
#          'to personalize': 3,
#          'we may': 18,
#          'ENTITY through': 10,
#          'store and': 2,
#          'strict confidentiality': 1,
#          'perform a': 3,
#          'outside the': 3,
#          'at your': 9,
#          'agree with': 1,
#          'heading below': 1,
#          'links to': 12,
#          'implemented under': 1,
#          'an employee': 1,
#          'help keep': 1,
#          'contracts discuss': 1,
#          'future by': 1,
#          'the actions': 2,
#          'cookies some': 2,
#          'the security': 10,
#          'order to': 17,
#          'can set': 2,
#          'ENTITY outlined': 1,
#          'hosts its': 1,
#          'specified provided': 1,
#          'the basis': 3,
#          'important to': 9,
#          'enforcing our': 1,
#          'You agree': 3,
#          'ENTITY where': 4,
#          'response to': 3,
#          'during the': 4,
#          'or its': 4,
#          'transferred across': 1,
#          'entering into': 2,
#          'as an': 3,
#          'error reports': 1,
#          'contain links': 8,
#          'ENTITY types': 1,
#          'adding new': 1,
#          'to time': 9,
#          'including contracts': 1,
#          'specified in': 2,
#          'problems in': 1,
#          'Error reports': 1,
#          'complying with': 4,
#          'and continually': 1,
#          'or destroyed': 1,
#          'withdraw your': 3,
#          'maintain the': 4,
#          'to exercise': 6,
#          'you and': 14,
#          'you under': 1,
#          'long as': 6,
#          'provide a': 8,
#          'and enforcing': 1,
#          'ENTITY as': 19,
#          'posting them': 1,
#          'addition you': 2,
#          'improve security': 1,
#          'from time': 8,
#          'for retention': 1,
#          'Collect heading': 1,
#          'provided a': 1,
#          'use that': 3,
#          'provide ENTITY': 10,
#          'into a': 3,
#          'communicate with': 8,
#          'by posting': 4,
#          'a contract': 4,
#          'as well': 17,
#          'Economic Area': 1,
#          'depends on': 2,
#          'and ultimately': 1,
#          'that feature': 2,
#          'not affect': 2,
#          'where ENTITY': 4,
#          'otherwise stated': 3,
#          'reports and': 1,
#          'other essential': 1,
#          'use to': 5,
#          'to perform': 6,
#          'an adequate': 2,
#          'other countries': 4,
#          'we store': 1,
#          'ENTITY testimonials': 1,
#          'the contract': 2,
#          'ENTITY interact': 1,
#          'discuss details': 1,
#          'our response': 1,
#          'that your': 9,
#          'are provided': 5,
#          'organizations that': 1,
#          'be located': 2,
#          'to comply': 10,
#          'ensure the': 4,
#          'no control': 4,
#          'you ENTITY': 11,
#          'type or': 3,
#          'new features': 2,
#          'time as': 2,
#          'periods can': 1,
#          'receive from': 4,
#          'through the': 10,
#          'to receiving': 2,
#          'name phone': 1,
#          'number of': 10,
#          'and fulfill': 1,
#          'about your': 14,
#          'that we': 19,
#          'rules and': 3,
#          'vary significantly': 1,
#          'network you': 1,
#          'ENTITY laws': 7,
#          'process ENTITY': 3,
#          'consent will': 1,
#          'legitimate requests': 1,
#          'in it': 1,
#          'is important': 8,
#          'us at': 5,
#          'for your': 11,
#          'may notify': 1,
#          'collect on': 2,
#          'control over': 9,
#          'of such': 12,
#          'our contracts': 1,
#          'The Updated': 1,
#          'to take': 4,
#          'The exact': 1,
#          'have been': 7,
#          'help ensure': 3,
#          'or templates': 1,
#          'and configuration': 1,
#          'so at': 2,
#          'in offering': 1,
#          'or some': 1,
#          'processing grounds': 1,
#          'approved by': 2,
#          'It is': 7,
#          'context of': 3,
#          'share information': 2,
#          'Section of': 1,
#          'and provide': 5,
#          'as your': 10,
#          'ENTITY explains': 1,
#          'object to': 4,
#          'visit the': 6,
#          'submit to': 1,
#          'cases these': 2,
#          'a legitimate': 2,
#          'situated in': 1,
#          'and protections': 1,
#          'who ENTITY': 2,
#          'as long': 5,
#          'affirmatively choose': 1,
#          'Because these': 1,
#          'exact ENTITY': 1,
#          'right mentioned': 1,
#          'name address': 15,
#          'you transmit': 3,
#          'affect the': 2,
#          'your consent': 8,
#          'the Updated': 1,
#          'collected upon': 1,
#          'contractual clauses': 2,
#          'some browser': 1,
#          'ENTITY cookies': 7,
#          'by contacting': 2,
#          'that our': 2,
#          'what ENTITY': 2,
#          'ENTITY Corp': 1,
#          'information as': 7,
#          'to potential': 1,
#          'or may': 3,
#          'take the': 1,
#          'you can': 10,
#          'to better': 6,
#          'ask ENTITY': 1,
#          'if the': 5,
#          'ENTITY Updated': 1,
#          'and language': 1,
#          'and under': 3,
#          'us discuss': 1,
#          'that better': 1,
#          'such cases': 1,
#          'well as': 15,
#          'project samples': 1,
#          'ENTITY correct': 1,
#          'we use': 10,
#          'the moment': 1,
#          'the network': 2,
#          'about the': 10,
#          'also includes': 3,
#          'vary for': 1,
#          'be collected': 5,
#          'date of': 3,
#          'may charge': 2,
#          'not be': 12,
#          'adviser consultant': 1,
#          'our commitment': 1,
#          'purposes such': 2,
#          'complex or': 1,
#          'example error': 1,
#          'concluded between': 1,
#          'security requirements': 1,
#          'located either': 1,
#          'and make': 1,
#          'to pay': 1,
#          'is clearly': 2,
#          'performance ENTITY': 1,
#          'prevent fraud': 4,
#          'content ENTITY': 3,
#          'reports to': 2,
#          'jurisdictions please': 1,
#          'is particularly': 1,
#          'all legitimate': 1,
#          'our agreements': 1,
#          'illegal activity': 3,
#          'offers to': 1,
#          'collected by': 8,
#          'improving the': 2,
#          'a reasonable': 2,
#          'keep you': 1,
#          'posting or': 1,
#          'processing from': 1,
#          'your use': 11,
#          'with ENTITY': 19,
#          'including adding': 1,
#          'your country': 4,
#          'than consent': 1,
#          'severity of': 1,
#          'contracts and': 1,
#          'appropriate business': 1,
#          'will it': 1,
#          'countries in': 2,
#          'we need': 6,
#          'features search': 1,
#          'and policies': 2,
#          'together with': 4,
#          'who can': 1,
#          'to another': 4,
#          'exchange signed': 1,
#          'fulfill the': 2,
#          'types actual': 1,
#          'the choices': 2,
#          'In addition': 6,
#          'and until': 2,
#          'USA as': 1,
#          'or refuse': 1,
#          'set or': 1,
#          'consent that': 2,
#          'you wish': 8,
#          'a live': 1,
#          'ENTITY store': 1,
#          'to object': 2,
#          'take steps': 3,
#          'legitimate interest': 2,
#          ...})

# %%
map(collections.Counter.elements,counters.values())
# Out:
# [<itertools.chain at 0x7feee2c1dfd0>,
#  <itertools.chain at 0x7feee2c1d550>,
#  <itertools.chain at 0x7feee2c1d438>,
#  <itertools.chain at 0x7feee2c1de48>,
#  <itertools.chain at 0x7feee2c1d908>,
#  <itertools.chain at 0x7feee2c1d400>,
#  <itertools.chain at 0x7feee2c1dc18>,
#  <itertools.chain at 0x7feee2c1d860>,
#  <itertools.chain at 0x7feee2c1d898>,
#  <itertools.chain at 0x7feee2c1d518>,
#  <itertools.chain at 0x7feee2c1d588>,
#  <itertools.chain at 0x7feee2c1d128>,
#  <itertools.chain at 0x7feee2c1d048>,
#  <itertools.chain at 0x7feee2c1df28>,
#  <itertools.chain at 0x7feee2c14278>,
#  <itertools.chain at 0x7feee2c149e8>,
#  <itertools.chain at 0x7feee2c14390>,
#  <itertools.chain at 0x7feee2c14438>,
#  <itertools.chain at 0x7feee2c14a58>,
#  <itertools.chain at 0x7feee2c14f28>,
#  <itertools.chain at 0x7feee2c147f0>,
#  <itertools.chain at 0x7feee2c14780>,
#  <itertools.chain at 0x7feee2c148d0>,
#  <itertools.chain at 0x7feee2c144a8>,
#  <itertools.chain at 0x7feee2c145f8>,
#  <itertools.chain at 0x7feee2c14c50>,
#  <itertools.chain at 0x7feee2c14128>,
#  <itertools.chain at 0x7feee2c14b70>,
#  <itertools.chain at 0x7feee2c14a90>,
#  <itertools.chain at 0x7feee2c14668>,
#  <itertools.chain at 0x7feee2c14048>,
#  <itertools.chain at 0x7feee2c14b38>,
#  <itertools.chain at 0x7feee2c14978>,
#  <itertools.chain at 0x7feee2c14470>,
#  <itertools.chain at 0x7feee2c147b8>,
#  <itertools.chain at 0x7feee2c14358>,
#  <itertools.chain at 0x7feee2c140b8>,
#  <itertools.chain at 0x7feee2c14e48>,
#  <itertools.chain at 0x7feee2c14860>,
#  <itertools.chain at 0x7feee2c14ef0>]

# %%
ys_values = sorted(list(counters.keys()))

# %%
phrases = set(itertools.chain.from_iterable(map(collections.Counter.elements,counters.values())))
trends = {
    phrase: [counters[ys][phrase] for ys in ys_values] for phrase in phrases
}

# %%
del phrases
for ys in ys_values:
    del counters[ys]
del counters

# %% [markdown]
# # Rank

# %%
def rank_phrases(key):
    ranks = [
        (phrase,key(counts)) for phrase, counts in trends.items()
    ]
    return sorted(ranks,key=lambda x: x[1],reverse=True)

rank_phrases(max)
# Out:
# [('ENTITY to', 58),
#  ('the ENTITY', 57),
#  ('ENTITY ENTITY', 57),
#  ('ENTITY and', 55),
#  ('our ENTITY', 54),
#  ('and ENTITY', 53),
#  ('to ENTITY', 52),
#  ('ENTITY is', 51),
#  ('ENTITY may', 51),
#  ('of ENTITY', 50),
#  ('If you', 50),
#  ('other ENTITY', 49),
#  ('ENTITY or', 48),
#  ('ENTITY address', 48),
#  ('by ENTITY', 47),
#  ('your ENTITY', 46),
#  ('of the', 46),
#  ('to the', 45),
#  ('this ENTITY', 45),
#  ('ENTITY of', 45),
#  ('do not', 44),
#  ('ENTITY in', 44),
#  ('in the', 44),
#  ('a ENTITY', 43),
#  ('to provide', 43),
#  ('may be', 43),
#  ('does not', 42),
#  ('This ENTITY', 42),
#  ('use of', 42),
#  ('ENTITY that', 42),
#  ('ENTITY you', 41),
#  ('for the', 40),
#  ('information about', 40),
#  ('on the', 40),
#  ('of our', 40),
#  ('or ENTITY', 39),
#  ('third parties', 38),
#  ('on our', 38),
#  ('ENTITY we', 38),
#  ('such as', 38),
#  ('ENTITY for', 38),
#  ('ENTITY on', 37),
#  ('to our', 36),
#  ('when you', 36),
#  ('to you', 36),
#  ('We may', 36),
#  ('use ENTITY', 36),
#  ('we will', 36),
#  ('the information', 36),
#  ('this information', 35),
#  ('and other', 35),
#  ('ENTITY by', 35),
#  ('these ENTITY', 35),
#  ('with ENTITY', 35),
#  ('ENTITY with', 35),
#  ('ENTITY from', 35),
#  ('you have', 35),
#  ('ENTITY as', 34),
#  ('ENTITY will', 34),
#  ('you may', 34),
#  ('information that', 33),
#  ('to protect', 33),
#  ('to your', 33),
#  ('will not', 33),
#  ('may use', 33),
#  ('ENTITY the', 33),
#  ('on ENTITY', 33),
#  ('and to', 33),
#  ('ENTITY about', 33),
#  ('your information', 32),
#  ('order to', 32),
#  ('information to', 32),
#  ('will be', 32),
#  ('are not', 32),
#  ('that you', 32),
#  ('to us', 32),
#  ('any ENTITY', 32),
#  ('may also', 32),
#  ('you are', 32),
#  ('use cookies', 31),
#  ('in order', 31),
#  ('We use', 31),
#  ('your name', 31),
#  ('cookies to', 31),
#  ('with the', 31),
#  ('ENTITY information', 31),
#  ('and the', 31),
#  ('ENTITY does', 31),
#  ('you to', 31),
#  ('ENTITY policies', 31),
#  ('information is', 30),
#  ('We do', 30),
#  ('ENTITY at', 30),
#  ('to this', 30),
#  ('we may', 30),
#  ('be used', 30),
#  ('it is', 30),
#  ('or to', 30),
#  ('ENTITY such', 30),
#  ('on your', 29),
#  ('is not', 29),
#  ('not be', 29),
#  ('ENTITY are', 29),
#  ('from ENTITY', 28),
#  ('to any', 28),
#  ('of this', 28),
#  ('of your', 28),
#  ('used to', 28),
#  ('The ENTITY', 28),
#  ('any information', 28),
#  ('that we', 28),
#  ('to be', 28),
#  ('or other', 28),
#  ('if you', 28),
#  ('at any', 28),
#  ('at the', 28),
#  ('the Internet', 28),
#  ('to time', 28),
#  ('at ENTITY', 28),
#  ('your computer', 28),
#  ('you do', 28),
#  ('personally ENTITY', 28),
#  ('of information', 27),
#  ('comply with', 27),
#  ('We will', 27),
#  ('us to', 27),
#  ('you can', 27),
#  ('your browser', 27),
#  ('time to', 27),
#  ('any time', 27),
#  ('can not', 27),
#  ('we collect', 27),
#  ('you visit', 27),
#  ('responsible for', 27),
#  ('about you', 27),
#  ('about ENTITY', 27),
#  ('and we', 27),
#  ('for ENTITY', 27),
#  ('such information', 26),
#  ('in a', 26),
#  ('You can', 26),
#  ('that ENTITY', 26),
#  ('choose to', 26),
#  ('to use', 26),
#  ('use the', 26),
#  ('ENTITY which', 26),
#  ('the use', 26),
#  ('can be', 26),
#  ('of any', 26),
#  ('its ENTITY', 25),
#  ('you ENTITY', 25),
#  ('we can', 25),
#  ('to other', 25),
#  ('in this', 25),
#  ('ENTITY has', 25),
#  ('number of', 25),
#  ('for any', 25),
#  ('as ENTITY', 25),
#  ('do so', 25),
#  ('right to', 25),
#  ('from time', 25),
#  ('based on', 25),
#  ('any other', 25),
#  ('information you', 24),
#  ('we use', 24),
#  ('provide you', 24),
#  ('and how', 24),
#  ('you provide', 24),
#  ('to help', 24),
#  ('we have', 24),
#  ('provide ENTITY', 24),
#  ('with our', 24),
#  ('ENTITY s', 24),
#  ('as a', 24),
#  ('ENTITY please', 24),
#  ('their ENTITY', 24),
#  ('that is', 24),
#  ('may ENTITY', 24),
#  ('of such', 23),
#  ('information collected', 23),
#  ('about your', 23),
#  ('able to', 23),
#  ('of these', 23),
#  ('information from', 23),
#  ('cookies and', 23),
#  ('you with', 23),
#  ('an ENTITY', 23),
#  ('information on', 23),
#  ('to serve', 23),
#  ('information in', 23),
#  ('is a', 23),
#  ('the right', 23),
#  ('required to', 23),
#  ('collect ENTITY', 22),
#  ('ENTITY when', 22),
#  ('also use', 22),
#  ('as your', 22),
#  ('collect information', 22),
#  ('ENTITY addresses', 22),
#  ('to a', 22),
#  ('not ENTITY', 22),
#  ('necessary to', 22),
#  ('by the', 22),
#  ('you will', 22),
#  ('ENTITY browser', 22),
#  ('as well', 22),
#  ('to comply', 22),
#  ('not to', 22),
#  ('ENTITY including', 22),
#  ('visits to', 22),
#  ('we are', 22),
#  ('used by', 22),
#  ('may not', 21),
#  ('advertising ENTITY', 21),
#  ('ENTITY uses', 21),
#  ('on a', 21),
#  ('changes to', 21),
#  ('from our', 21),
#  ('links to', 21),
#  ('is used', 21),
#  ('ENTITY who', 21),
#  ('agree to', 21),
#  ('well as', 21),
#  ('the content', 21),
#  ('may include', 21),
#  ('to third', 21),
#  ('ENTITY can', 21),
#  ('how we', 21),
#  ('from you', 21),
#  ('These ENTITY', 21),
#  ('about our', 21),
#  ('subject to', 21),
#  ('about the', 21),
#  ('with your', 21),
#  ('such ENTITY', 21),
#  ('You may', 21),
#  ('s ENTITY', 21),
#  ('that the', 21),
#  ('wish to', 20),
#  ('linked to', 20),
#  ('under the', 20),
#  ('Our ENTITY', 20),
#  ('use your', 20),
#  ('A ENTITY', 20),
#  ('part of', 20),
#  ('accordance with', 20),
#  ('information for', 20),
#  ('to improve', 20),
#  ('When you', 20),
#  ('help us', 20),
#  ('not responsible', 20),
#  ('in your', 20),
#  ('or the', 20),
#  ('or otherwise', 20),
#  ('information we', 20),
#  ('we do', 20),
#  ('hard drive', 20),
#  ('In addition', 20),
#  ('in ENTITY', 20),
#  ('any of', 20),
#  ('with a', 20),
#  ('telephone number', 20),
#  ('information and', 20),
#  ('any questions', 20),
#  ('serve ads', 20),
#  ('the time', 20),
#  ('address and', 20),
#  ('consent to', 19),
#  ('as the', 19),
#  ('need to', 19),
#  ('to identify', 19),
#  ('in accordance', 19),
#  ('ENTITY provider', 19),
#  ('that information', 19),
#  ('certain ENTITY', 19),
#  ('to do', 19),
#  ('ENTITY our', 19),
#  ('protect the', 19),
#  ('to receive', 19),
#  ('of interest', 19),
#  ('may share', 19),
#  ('ENTITY use', 19),
#  ('you choose', 19),
#  ('the security', 19),
#  ('from the', 19),
#  ('We also', 19),
#  ('you and', 19),
#  ('so that', 19),
#  ('of a', 19),
#  ('not sell', 19),
#  ('name address', 19),
#  ('The information', 19),
#  ('out of', 19),
#  ('committed to', 19),
#  ('that are', 19),
#  ('which you', 19),
#  ('ENTITY your', 18),
#  ('types of', 18),
#  ('By using', 18),
#  ('ENTITY practices', 18),
#  ('use and', 18),
#  ('be able', 18),
#  ('is collected', 18),
#  ('collected by', 18),
#  ('on this', 18),
#  ('security of', 18),
#  ('ENTITY under', 18),
#  ('information may', 18),
#  ('please ENTITY', 18),
#  ('through the', 18),
#  ('note that', 18),
#  ('or any', 18),
#  ('to have', 18),
#  ('send you', 18),
#  ('unauthorized ENTITY', 18),
#  ('For example', 18),
#  ('ensure that', 18),
#  ('to send', 18),
#  ('interest to', 18),
#  ('to collect', 18),
#  ('type of', 18),
#  ('for a', 18),
#  ('may collect', 18),
#  ('respond to', 18),
#  ('protect ENTITY', 18),
#  ('and use', 18),
#  ('in any', 18),
#  ('If we', 18),
#  ('to or', 17),
#  ('address or', 17),
#  ('all ENTITY', 17),
#  ('all of', 17),
#  ('We are', 17),
#  ('it to', 17),
#  ('stored on', 17),
#  ('only to', 17),
#  ('information with', 17),
#  ('This information', 17),
#  ('required by', 17),
#  ('your consent', 17),
#  ('have any', 17),
#  ('you when', 17),
#  ('visit ENTITY', 17),
#  ('provided to', 17),
#  ('and will', 17),
#  ('address ENTITY', 17),
#  ('using the', 17),
#  ('to keep', 17),
#  ('is necessary', 17),
#  ('including ENTITY', 17),
#  ('new ENTITY', 17),
#  ('disclose ENTITY', 17),
#  ('name ENTITY', 17),
#  ('Cookies are', 17),
#  ('uses cookies', 17),
#  ('or in', 17),
#  ('which ENTITY', 16),
#  ('of cookies', 16),
#  ('control over', 16),
#  ('also be', 16),
#  ('may have', 16),
#  ('certain information', 16),
#  ('and any', 16),
#  ('This is', 16),
#  ('visitors to', 16),
#  ('to make', 16),
#  ('about how', 16),
#  ('to ensure', 16),
#  ('visit to', 16),
#  ('have ENTITY', 16),
#  ('use this', 16),
#  ('the same', 16),
#  ('provide us', 16),
#  ('one of', 16),
#  ('Your ENTITY', 16),
#  ('for your', 16),
#  ('protect your', 16),
#  ('to change', 16),
#  ('you use', 16),
#  ('provide to', 16),
#  ('and is', 16),
#  ('ENTITY applies', 16),
#  ('browser type', 16),
#  ('opt out', 16),
#  ('accept cookies', 16),
#  ('Please note', 16),
#  ('under NUMBER', 16),
#  ('information or', 16),
#  ('the purposes', 16),
#  ('visit our', 16),
#  ('some of', 16),
#  ('to analyze', 16),
#  ('using ENTITY', 16),
#  ('more information', 16),
#  ('by us', 16),
#  ('including your', 16),
#  ('ENTITY if', 16),
#  ('to disclose', 16),
#  ('with this', 16),
#  ('your preferences', 16),
#  ('ENTITY collects', 16),
#  ('collect and', 16),
#  ('own ENTITY', 16),
#  ('the following', 16),
#  ('have the', 16),
#  ('measures to', 16),
#  ('use information', 15),
#  ('as necessary', 15),
#  ('interact with', 15),
#  ('compliance with', 15),
#  ('apply to', 15),
#  ('you should', 15),
#  ('your visits', 15),
#  ('will only', 15),
#  ('over the', 15),
#  ('will also', 15),
#  ('with us', 15),
#  ('security measures', 15),
#  ('and are', 15),
#  ('not guarantee', 15),
#  ('respect to', 15),
#  ('improve our', 15),
#  ('purpose of', 15),
#  ('reserve the', 15),
#  ('ask you', 15),
#  ('that may', 15),
#  ('use our', 15),
#  ('with respect', 15),
#  ('to and', 15),
#  ('or by', 15),
#  ('your personally', 15),
#  ('ENTITY through', 15),
#  ('and our', 15),
#  ('your account', 15),
#  ('that your', 15),
#  ('phone number', 15),
#  ('ENTITY advertising', 15),
#  ('without your', 15),
#  ('We collect', 15),
#  ('provided by', 15),
#  ('your use', 15),
#  ('ENTITY page', 15),
#  ('in which', 15),
#  ('age of', 15),
#  ('share ENTITY', 15),
#  ('that it', 15),
#  ('would like', 15),
#  ('cookies or', 15),
#  ('time you', 15),
#  ('through ENTITY', 15),
#  ('and may', 15),
#  ('with any', 15),
#  ('used for', 15),
#  ('use it', 15),
#  ('for example', 15),
#  ('connection with', 15),
#  ('the future', 15),
#  ('not use', 15),
#  ('from us', 15),
#  ('the age', 15),
#  ('in our', 15),
#  ('and in', 14),
#  ('It is', 14),
#  ('You should', 14),
#  ('collected from', 14),
#  ('Internet ENTITY', 14),
#  ('and does', 14),
#  ('ENTITY it', 14),
#  ('and your', 14),
#  ('are a', 14),
#  ('specific ENTITY', 14),
#  ('you would', 14),
#  ('that they', 14),
#  ('to such', 14),
#  ('a small', 14),
#  ('important to', 14),
#  ('you about', 14),
#  ('ENTITY experience', 14),
#  ('participate in', 14),
#  ('to protecting', 14),
#  ('ENTITY marketing', 14),
#  ('browser ENTITY', 14),
#  ('of those', 14),
#  ('is committed', 14),
#  ('to read', 14),
#  ('operating system', 14),
#  ('of their', 14),
#  ('will use', 14),
#  ('ENTITY a', 14),
#  ('us in', 14),
#  ('us or', 14),
#  ('cookies are', 14),
#  ('of NUMBER', 14),
#  ('policies of', 14),
#  ('link to', 14),
#  ('aware that', 14),
#  ('to track', 14),
#  ('information will', 14),
#  ('no ENTITY', 14),
#  ('the collection', 14),
#  ('or use', 14),
#  ('ENTITY based', 14),
#  ('visit the', 14),
#  ('their own', 14),
#  ('shared with', 14),
#  ('is important', 14),
#  ('not control', 14),
#  ('or as', 14),
#  ('content and', 14),
#  ('to accept', 14),
#  ('to information', 14),
#  ('this page', 14),
#  ('visiting ENTITY', 14),
#  ('you wish', 14),
#  ('name and', 14),
#  ('ENTITY without', 14),
#  ('and you', 14),
#  ('with you', 14),
#  ('with other', 14),
#  ('other than', 14),
#  ('but not', 14),
#  ('those ENTITY', 14),
#  ('and security', 14),
#  ('described in', 14),
#  ('ENTITY pages', 14),
#  ('the purpose', 14),
#  ('in connection', 14),
#  ('read the', 14),
#  ('you or', 14),
#  ('us with', 14),
#  ('ENTITY provided', 14),
#  ('cookies you', 14),
#  ('disclosure of', 14),
#  ('not share', 13),
#  ('address to', 13),
#  ('We have', 13),
#  ('browser to', 13),
#  ('you register', 13),
#  ('of receiving', 13),
#  ('related to', 13),
#  ('you from', 13),
#  ('marketing purposes', 13),
#  ('stored in', 13),
#  ('ENTITY only', 13),
#  ('NUMBER ENTITY', 13),
#  ('ENTITY account', 13),
#  ('necessary for', 13),
#  ('processing of', 13),
#  ('as described', 13),
#  ('browser and', 13),
#  ('we believe', 13),
#  ('from other', 13),
#  ('on their', 13),
#  ('time by', 13),
#  ('we make', 13),
#  ('our behalf', 13),
#  ('a link', 13),
#  ('control the', 13),
#  ('our business', 13),
#  ('administer the', 13),
#  ('may contain', 13),
#  ('you agree', 13),
#  ('and for', 13),
#  ('communicate with', 13),
#  ('goods and', 13),
#  ('for you', 13),
#  ('information such', 13),
#  ('up to', 13),
#  ('have a', 13),
#  ('long as', 13),
#  ('us at', 13),
#  ('ENTITY laws', 13),
#  ('has been', 13),
#  ('is ENTITY', 13),
#  ('applies to', 13),
#  ('which we', 13),
#  ('ENTITY also', 13),
#  ('to understand', 13),
#  ('to better', 13),
#  ('parties for', 13),
#  ('another ENTITY', 13),
#  ('example we', 13),
#  ('be aware', 13),
#  ('are small', 13),
#  ('is required', 13),
#  ('ENTITY but', 13),
#  ('or for', 13),
#  ('In order', 13),
#  ('practices of', 13),
#  ('are required', 13),
#  ('or telephone', 13),
#  ('notify you', 13),
#  ('that a', 13),
#  ('us and', 13),
#  ('is to', 13),
#  ('are used', 13),
#  ('ENTITY number', 13),
#  ('content of', 13),
#  ('policies and', 13),
#  ('the practices', 13),
#  ('you of', 12),
#  ('can also', 12),
#  ('to share', 12),
#  ('you consent', 12),
#  ('disable cookies', 12),
#  ('purposes of', 12),
#  ('to store', 12),
#  ('at your', 12),
#  ('Some of', 12),
#  ('are committed', 12),
#  ('In the', 12),
#  ('for purposes', 12),
#  ('computer or', 12),
#  ('available to', 12),
#  ('cookies ENTITY', 12),
#  ('information ENTITY', 12),
#  ('about this', 12),
#  ('using our', 12),
#  ('ENTITY so', 12),
#  ('any changes', 12),
#  ('use or', 12),
#  ('and information', 12),
#  ('for marketing', 12),
#  ('to allow', 12),
#  ('about goods', 12),
#  ('ability to', 12),
#  ('when we', 12),
#  ('We encourage', 12),
#  ('be transferred', 12),
#  ('ENTITY collected', 12),
#  ('not have', 12),
#  ('ENTITY certain', 12),
#  ('for us', 12),
#  ('or if', 12),
#  ('be collected', 12),
#  ('share your', 12),
#  ('the public', 12),
#  ('protection of', 12),
#  ('by any', 12),
#  ('ENTITY have', 12),
#  ('is subject', 12),
#  ('like to', 12),
#  ('or control', 12),
#  ('of its', 12),
#  ('which may', 12),
#  ('a particular', 12),
#  ('and gather', 12),
#  ('all information', 12),
#  ('or disclosure', 12),
#  ('each ENTITY', 12),
#  ('safety of', 12),
#  ('encourage you', 12),
#  ('with information', 12),
#  ('to process', 12),
#  ('ads on', 12),
#  ('you submit', 12),
#  ('with third', 12),
#  ('questions about', 12),
#  ('identify you', 12),
#  ('applicable ENTITY', 12),
#  ('how to', 12),
#  ('to recognize', 12),
#  ('We reserve', 12),
#  ('you in', 12),
#  ('may disclose', 12),
#  ('to prevent', 12),
#  ('ENTITY this', 12),
#  ('include ENTITY', 12),
#  ('those changes', 12),
#  ('also collect', 12),
#  ('or a', 12),
#  ('asked to', 12),
#  ('how ENTITY', 12),
#  ('ENTITY cookies', 11),
#  ('each time', 11),
#  ('provide advertisements', 11),
#  ('following the', 11),
#  ('aware of', 11),
#  ('the event', 11),
#  ('this and', 11),
#  ('pages you', 11),
#  ('and not', 11),
#  ('should be', 11),
#  ('or others', 11),
#  ('and improve', 11),
#  ('variety of', 11),
#  ('ENTITY enforcement', 11),
#  ('as long', 11),
#  ('want to', 11),
#  ('ENTITY not', 11),
#  ('including but', 11),
#  ('information including', 11),
#  ('pages and', 11),
#  ('ads to', 11),
#  ('it may', 11),
#  ('ENTITY enables', 11),
#  ('For more', 11),
#  ('to their', 11),
#  ('parts of', 11),
#  ('or our', 11),
#  ('no longer', 11),
#  ('acceptance of', 11),
#  ('your experience', 11),
#  ('a variety', 11),
#  ('our visitors', 11),
#  ('of all', 11),
#  ('ENTITY name', 11),
#  ('ENTITY browsers', 11),
#  ('not knowingly', 11),
#  ('the browser', 11),
#  ('your own', 11),
#  ('you the', 11),
#  ('by these', 11),
#  ('by your', 11),
#  ('collected and', 11),
#  ('cookies by', 11),
#  ('ENTITY using', 11),
#  ('information regarding', 11),
#  ('through your', 11),
#  ('that any', 11),
#  ('to respond', 11),
#  ('to maintain', 11),
#  ('cookies on', 11),
#  ('for their', 11),
#  ('any such', 11),
#  ('your hard', 11),
#  ('regarding the', 11),
#  ('to deliver', 11),
#  ('not cover', 11),
#  ('of other', 11),
#  ('be asked', 11),
#  ('improve the', 11),
#  ('ENTITY offered', 11),
#  ('can choose', 11),
#  ('prior to', 11),
#  ('not collect', 11),
#  ('may provide', 11),
#  ('parties who', 11),
#  ('ENTITY statement', 11),
#  ('ENTITY track', 11),
#  ('be of', 11),
#  ('more about', 11),
#  ('not want', 11),
#  ('for our', 11),
#  ('from a', 11),
#  ('which is', 11),
#  ('at our', 11),
#  ('by third', 11),
#  ('to enhance', 11),
#  ('the processing', 11),
#  ('have no', 11),
#  ('address phone', 11),
#  ('continued use', 11),
#  ('track ENTITY', 11),
#  ('sent to', 11),
#  ('NUMBER years', 11),
#  ('click here', 11),
#  ('you for', 11),
#  ('time of', 11),
#  ('internet protocol', 11),
#  ('These cookies', 11),
#  ('we disclose', 11),
#  ('learn more', 11),
#  ('some cases', 11),
#  ('opportunity to', 11),
#  ('ENTITY contains', 11),
#  ('you an', 11),
#  ('be shared', 11),
#  ('where you', 11),
#  ('in place', 11),
#  ('in these', 11),
#  ('files that', 11),
#  ('and used', 11),
#  ('using this', 11),
#  ('purposes and', 11),
#  ('if we', 11),
#  ('is in', 10),
#  ('to all', 10),
#  ('areas of', 10),
#  ('advertisements and', 10),
#  ('to verify', 10),
#  ('means of', 10),
#  ('continue to', 10),
#  ('with applicable', 10),
#  ('not disclose', 10),
#  ('not apply', 10),
#  ('function properly', 10),
#  ('who have', 10),
#  ('to assist', 10),
#  ('ENTITY features', 10),
#  ('transferred to', 10),
#  ('regarding your', 10),
#  ('have been', 10),
#  ('trends administer', 10),
#  ('that such', 10),
#  ('the date', 10),
#  ('you as', 10),
#  ('Please read', 10),
#  ('will post', 10),
#  ('from your', 10),
#  ('our online', 10),
#  ('ENTITY management', 10),
#  ('collect or', 10),
#  ('recognize your', 10),
#  ('information as', 10),
#  ('response to', 10),
#  ('networks to', 10),
#  ('ENTITY online', 10),
#  ('information when', 10),
#  ('information which', 10),
#  ('collect any', 10),
#  ('advertisements on', 10),
#  ('that can', 10),
#  ('and that', 10),
#  ('time and', 10),
#  ('to delete', 10),
#  ('cookies that', 10),
#  ('only be', 10),
#  ('please do', 10),
#  ('provide information', 10),
#  ('the type', 10),
#  ('is the', 10),
#  ('store information', 10),
#  ('browser is', 10),
#  ('questions or', 10),
#  ('amount of', 10),
#  ('the number', 10),
#  ('posted on', 10),
#  ('analyze trends', 10),
#  ('believe that', 10),
#  ('them to', 10),
#  ('decide to', 10),
#  ('your visit', 10),
#  ('is stored', 10),
#  ('legal process', 10),
#  ('may change', 10),
#  ('ad networks', 10),
#  ('ENTITY NUMBER', 10),
#  ('or property', 10),
#  ('include the', 10),
#  ('around the', 10),
#  ('give us', 10),
#  ('activities on', 10),
#  ('the extent', 10),
#  ('may send', 10),
#  ('other third', 10),
#  ('unless we', 10),
#  ('to know', 10),
#  ('process ENTITY', 10),
#  ('to enable', 10),
#  ('directly to', 10),
#  ('uses ENTITY', 10),
#  ('to these', 10),
#  ('by you', 10),
#  ('and practices', 10),
#  ('online ENTITY', 10),
#  ('ENTITY unless', 10),
#  ('enables it', 10),
#  ('or you', 10),
#  ('a secure', 10),
#  ('features of', 10),
#  ('collection of', 10),
#  ('such other', 10),
#  ('the way', 10),
#  ('provide a', 10),
#  ('ENTITY link', 10),
#  ('any personally', 10),
#  ('unless you', 10),
#  ('practices and', 10),
#  ('computer hard', 10),
#  ('rights or', 10),
#  ('sign up', 10),
#  ('ENTITY includes', 10),
#  ('can ENTITY', 10),
#  ('on any', 10),
#  ('we receive', 10),
#  ('by our', 10),
#  ('As a', 10),
#  ('you by', 10),
#  ('activities of', 10),
#  ('various ENTITY', 10),
#  ('which are', 10),
#  ('better ENTITY', 10),
#  ('to measure', 10),
#  ('so by', 10),
#  ('their visit', 10),
#  ('may update', 10),
#  ('You are', 10),
#  ('to enter', 10),
#  ('to of', 10),
#  ('addresses and', 10),
#  ('Please be', 10),
#  ('and can', 10),
#  ('and provide', 10),
#  ('and its', 10),
#  ('and conditions', 10),
#  ('governed by', 10),
#  ('by a', 10),
#  ('to perform', 10),
#  ('by using', 10),
#  ('to them', 10),
#  ('understand how', 10),
#  ('provide the', 10),
#  ('associated with', 10),
#  ('to learn', 10),
#  ('disclose your', 10),
#  ('and which', 10),
#  ('not agree', 10),
#  ('through our', 10),
#  ('designed to', 10),
#  ('knowingly collect', 10),
#  ('will notify', 10),
#  ('relating to', 10),
#  ('NUMBER NUMBER', 10),
#  ('by contacting', 10),
#  ('ENTITY stored', 10),
#  ('agree that', 10),
#  ('changes on', 10),
#  ('for more', 10),
#  ('the ability', 10),
#  ('that if', 9),
#  ('ENTITY preferences', 9),
#  ('information can', 9),
#  ('effectiveness of', 9),
#  ('NUMBER secure', 9),
#  ('click on', 9),
#  ('to complete', 9),
#  ('to that', 9),
#  ('when they', 9),
#  ('your interests', 9),
#  ('assist us', 9),
#  ('ENTITY visitors', 9),
#  ('NUMBER days', 9),
#  ('parties without', 9),
#  ('when a', 9),
#  ('receive ENTITY', 9),
#  ('it will', 9),
#  ('and store', 9),
#  ('by visiting', 9),
#  ('send us', 9),
#  ('protocol ENTITY', 9),
#  ('contains links', 9),
#  ('the effectiveness', 9),
#  ('inform you', 9),
#  ('and agree', 9),
#  ('refer to', 9),
#  ('computer and', 9),
#  ('you voluntarily', 9),
#  ('and disclosure', 9),
#  ('not contain', 9),
#  ('our advertising', 9),
#  ('technical and', 9),
#  ('outside of', 9),
#  ('made available', 9),
#  ('At ENTITY', 9),
#  ('and all', 9),
#  ('subscribe to', 9),
#  ('of certain', 9),
#  ('contacting us', 9),
#  ('collected through', 9),
#  ('an order', 9),
#  ('to give', 9),
#  ('not include', 9),
#  ('ENTITY within', 9),
#  ('known as', 9),
#  ('security and', 9),
#  ('store your', 9),
#  ('our legal', 9),
#  ('and where', 9),
#  ('or share', 9),
#  ('these third', 9),
#  ('of each', 9),
#  ('is being', 9),
#  ('it and', 9),
#  ('to participate', 9),
#  ('there is', 9),
#  ('bottom of', 9),
#  ('In some', 9),
#  ('maintain the', 9),
#  ('make any', 9),
#  ('the rights', 9),
#  ('improve ENTITY', 9),
#  ('ENTITY server', 9),
#  ('who may', 9),
#  ('for which', 9),
#  ('ENTITY after', 9),
#  ('or that', 9),
#  ('order or', 9),
#  ('use a', 9),
#  ('all cookies', 9),
#  ('Secure ENTITY', 9),
#  ('to personalize', 9),
#  ('appear on', 9),
#  ('to notify', 9),
#  ('to refuse', 9),
#  ('ENTITY technology', 9),
#  ('loss misuse', 9),
#  ('and address', 9),
#  ('the pages', 9),
#  ('behalf of', 9),
#  ...]
